# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# enter the path in your Drive to assignment7
# e.g. 'cs231n/assignments/assignment7/'
FOLDERNAME = None

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %cd drive/My\ Drive
# %cd $FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content/drive/My Drive/Colab Notebooks/homework8/hw8_files_sol

# %%
# !pip install tensorboardX
# !pip install box2d-py
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install gym pyvirtualdisplay > /dev/null 2>&1

# %cp lunar_lander.py /usr/local/lib/python3.6/dist-packages/gym/envs/box2d/lunar_lander.py

# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# # Q1

# %%
# !bash xvfb-run -a -s "-screen 0 500x500x24" python run_dqn_atari.py
# Out:
# Logging data to /content/drive/My Drive/Colab Notebooks/homework8/hw8_files_sol/2020_06_14_16_55_06_566394_UTC__5e5c74ea-6e91-4f99-a196-632067627bfe/log.txt
# random seed = 1
# AVAILABLE GPUS:  ['device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0']
# ------------------------------------------------
# |                   timestep |           1e+04 |
# | mean reward (100 episodes) |            -234 |
# |           best mean reward |            -inf |
# |                   episodes |              73 |
# |                exploration |           0.804 |
# |              learning_rate |           0.001 |
# |               running time |           0.573 |
# ------------------------------------------------
# ------------------------------------------------
# |                   timestep |           2e+04 |
# | mean reward (100 episodes) |            -181 |
# |           best mean reward |            -181 |
# ...

# %%
#!bash python plot.py LOG_DIRECTORY
# !bash python plot.py 2020_06_14_16_55_06_566394_UTC__5e5c74ea-6e91-4f99-a196-632067627bfe

plt.figure()
img = cv2.imread("lunar_lander.png")
plt.axis('off')
plt.imshow(img)
# Out:
# Plot saved to lunar_lander.png

# %% [markdown]
# #Q2

# %%
# !bash xvfb-run -a -s "-screen 0 500x500x24" python train_pg_f18.py
# Out:
# Result dir: vpg_CartPole-v0_14-06-2020_16-26-40
# Running experiment with seed 1
# Logging data to vpg_CartPole-v0_14-06-2020_16-26-40/1/log.txt
# ********** Iteration 0 ************
# ----------------------------------------
# |               Time |              12 |
# |          Iteration |               0 |
# |        mean reward |            22.3 |
# |         std reward |            10.9 |
# |         max reward |              81 |
# |         min reward |               8 |
# |          EpLenMean |            22.3 |
# |           EpLenStd |            10.9 |
# | TimestepsThisBatch |           1e+04 |
# |     TimestepsSoFar |           1e+04 |
# ----------------------------------------
# ********** Iteration 1 ************
# ----------------------------------------
# |               Time |            20.6 |
# |          Iteration |               1 |
# |        mean reward |              31 |
# |         std reward |            15.3 |
# |         max reward |              98 |
# ...

# %%
# !bash python plot.py vpg_CartPole-v0_14-06-2020_16-26-40 -vpg --value='mean reward' 

plt.figure()
img = cv2.imread("cartpole.png")
plt.axis('off')
plt.imshow(img)
# Out:
# Plot saved to cartpole.png

# %%
# !bash xvfb-run -a -s "-screen 0 500x500x24" python train_pg_f18.py -rtg
# Out:
# Result dir: vpg_CartPole-v0_14-06-2020_16-33-27
# Running experiment with seed 1
# Logging data to vpg_CartPole-v0_14-06-2020_16-33-27/1/log.txt
# ********** Iteration 0 ************
# ----------------------------------------
# |               Time |            12.1 |
# |          Iteration |               0 |
# |        mean reward |            22.3 |
# |         std reward |            10.9 |
# |         max reward |              81 |
# |         min reward |               8 |
# |          EpLenMean |            22.3 |
# |           EpLenStd |            10.9 |
# | TimestepsThisBatch |           1e+04 |
# |     TimestepsSoFar |           1e+04 |
# ----------------------------------------
# ********** Iteration 1 ************
# ----------------------------------------
# |               Time |            20.6 |
# |          Iteration |               1 |
# |        mean reward |            32.1 |
# |         std reward |            16.2 |
# |         max reward |             137 |
# ...

# %%
# !bash python plot.py vpg_CartPole-v0_14-06-2020_16-33-27 -vpg --value='mean reward' 

plt.figure()
img = cv2.imread("cartpole.png")
plt.axis('off')
plt.imshow(img)
# Out:
# Plot saved to cartpole.png

# %%
# !bash xvfb-run -a -s "-screen 0 500x500x24" python train_pg_f18.py --nn_baseline
# Out:
# Result dir: vpg_CartPole-v0_14-06-2020_16-40-10
# Running experiment with seed 1
# Logging data to vpg_CartPole-v0_14-06-2020_16-40-10/1/log.txt
# ********** Iteration 0 ************
# ----------------------------------------
# |               Time |            12.5 |
# |          Iteration |               0 |
# |        mean reward |            22.3 |
# |         std reward |            10.9 |
# |         max reward |              81 |
# |         min reward |               8 |
# |          EpLenMean |            22.3 |
# |           EpLenStd |            10.9 |
# | TimestepsThisBatch |           1e+04 |
# |     TimestepsSoFar |           1e+04 |
# ----------------------------------------
# ********** Iteration 1 ************
# ----------------------------------------
# |               Time |            21.4 |
# |          Iteration |               1 |
# |        mean reward |            32.7 |
# |         std reward |            18.1 |
# |         max reward |             116 |
# ...

# %%
# !bash python plot.py vpg_CartPole-v0_14-06-2020_16-40-10 -vpg --value='mean reward' 

plt.figure()
img = cv2.imread("cartpole.png")
plt.axis('off')
plt.imshow(img)
# Out:
# Plot saved to cartpole.png
